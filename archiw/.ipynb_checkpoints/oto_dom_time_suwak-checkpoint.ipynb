# %% [markdown]
# Geokodowanie ogloszen sprzedarzy w Krakowie, ogloszenia z  okresu 2019-03 : 2019-12
#
# dane sciagniete skryptem:
#
# https://ofedoruk.pl/szukamy-mieszkania-za-pomoca-pythona-i-beautiful-soup/,

# %%
import sys
reload(sys)
sys.setdefaultencoding("utf-8")

import numpy as np 
import pandas as pd 
import seaborn as sns
import datetime
import time 
import geopandas as gpd
import difflib
from difflib import SequenceMatcher

# %%
df1 = pd.read_csv('geokodking_20200107.csv', header = 0, sep = ",", error_bad_lines=False)

#df1['data'] = df['data'].astype('str')
#df1["data"] = df1["data"].str.split(",", n = 1, expand = True)
#df1['data'] = df1['data'].replace('-','', regex=True)

df1['data'] = pd.to_datetime(df1['data'], format ='%Y-%m-%d %H:%M:%S')
# konwersja na format daty
df = df1.iloc[:1000]

# %%
# wyswietlenie punktow na heat mapie dynamicznej https://medium.com/nuances-of-programming/%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7-%D0%B0%D0%B2%D1%82%D0%BE%D0%B0%D0%B2%D0%B0%D1%80%D0%B8%D0%B9-%D0%B2-%D0%B1%D0%B0%D1%80%D1%81%D0%B5%D0%BB%D0%BE%D0%BD%D0%B5-%D1%81-%D0%B8%D1%81%D0%BF%D0%BE%D0%BB%D1%8C%D0%B7%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5%D0%BC-pandas-matplotlib-%D0%B8-folium-422f0587e528
from folium import plugins
from folium.plugins import HeatMapWithTime

max_amount = 100
m = folium.Map(location=[50.05, 19.95], zoom_start=12, )

hour_list = [[] for _ in range(24)]
for lat,log,hour in zip(df.latitude,df.longitude,df.data.dt.hour):
    hour_list[hour].append([lat,log]) 
    index = [str(i)+' Hours' for i in range(24)]
    
# Создание тепловой карты с объектом time для автомобильных аварий
HeatMapWithTime(hour_list, index).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for hour in df_copy.hour.sort_values().unique():
    display(hour)
# Out:
# 11.0
# 15.0
